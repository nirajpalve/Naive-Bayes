# %%
import pandas as pd       # Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
Train_Data = pd.read_csv("SalaryData_Train.CSV")     # Loading Train - DataSet
Train_Data
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
Train_Data.shape    # Dimension of test data
# Out:
# (30161, 14)

# %%
Train_Data.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
Train_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
Train_Data.describe(include = "all")
# Out:
#                  age workclass education   educationno        maritalstatus  \
# count   30161.000000     30161     30161  30161.000000                30161
# unique           NaN         7        16           NaN                    7
# top              NaN   Private   HS-grad           NaN   Married-civ-spouse
# freq             NaN     22285      9840           NaN                14065
# mean       38.438115       NaN       NaN     10.121316                  NaN
# std        13.134830       NaN       NaN      2.550037                  NaN
# min        17.000000       NaN       NaN      1.000000                  NaN
# 25%        28.000000       NaN       NaN      9.000000                  NaN
# 50%        37.000000       NaN       NaN     10.000000                  NaN
# 75%        47.000000       NaN       NaN     13.000000                  NaN
# max        90.000000       NaN       NaN     16.000000                  NaN
#
# ...

# %%
Train_Data.describe(include = "all").nunique()
# Out:
# age              8
# workclass        4
# education        4
# educationno      8
# maritalstatus    4
# occupation       4
# relationship     4
# race             4
# sex              4
# capitalgain      5
# capitalloss      5
# hoursperweek     7
# native           4
# Salary           4
# dtype: int64

# %%
Label = LabelEncoder()

# %%
Train_Data['workclass'] = Label.fit_transform(Train_Data['workclass'])
Train_Data['education'] = Label.fit_transform(Train_Data['education'])
Train_Data['maritalstatus'] = Label.fit_transform(Train_Data['maritalstatus'])
Train_Data['occupation'] = Label.fit_transform(Train_Data['occupation'])
Train_Data['relationship'] = Label.fit_transform(Train_Data['relationship'])
Train_Data['race'] = Label.fit_transform(Train_Data['race'])
Train_Data['sex'] = Label.fit_transform(Train_Data['sex'])
Train_Data['native'] = Label.fit_transform(Train_Data['native'])
Train_Data['Salary'] = Label.fit_transform(Train_Data['Salary'])

# %%
Train_Data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
Train_Data.dtypes
# Out:
# age              int64
# workclass        int32
# education        int32
# educationno      int64
# maritalstatus    int32
# occupation       int32
# relationship     int32
# race             int32
# sex              int32
# capitalgain      int64
# capitalloss      int64
# hoursperweek     int64
# native           int32
# Salary           int32
# dtype: object

# %% [markdown]
# # Model Building

# %%
X = Train_Data.drop(['Salary'], axis = 1)
Y = Train_Data['Salary']

# %%
X
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30156    0
# 30157    1
# 30158    0
# 30159    0
# 30160    1
# Name: Salary, Length: 30161, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size = 0.20, random_state = 42)

# %%
X_Train.shape, Y_Train.shape
# Out:
# ((24128, 13), (24128,))

# %%
X_Test.shape, Y_Test.shape
# Out:
# ((6033, 13), (6033,))

# %% [markdown]
# ## Model Training & Testing

# %%
from sklearn.naive_bayes import MultinomialNB as MB

# %%
classifier_mb = MB()

# %%
classifier_mb.fit(X_Train, Y_Train)
MB()
# Out:
# MultinomialNB()

# %%
Y_pred = classifier_mb.predict(X_Test)
Y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, classification_report

# %%
print("Accurracy Score:", round(accuracy_score(Y_Test, Y_pred), 4))
# Out:
# Accurracy Score: 0.7679

# %%
print("Precision Score:", round(precision_score(Y_Test, Y_pred), 4))
# Out:
# Precision Score: 0.6433

# %%
print("Confusion Matrix:", confusion_matrix(Y_Test, Y_pred))
# Out:
# Confusion Matrix: [[4312  178]
#  [1222  321]]

# %%
print("Classification Report: ", classification_report(Y_Test, Y_pred))
# Out:
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.78      0.96      0.86      4490
#            1       0.64      0.21      0.31      1543
#
#     accuracy                           0.77      6033
#    macro avg       0.71      0.58      0.59      6033
# weighted avg       0.74      0.77      0.72      6033

# %% [markdown]
# ## Deployment

# %%
from pickle import dump, load

# %%
dump(classifier_mb, open('logclassifier_mb.plktrain', 'wb'))

# %%
classifier_mb_pickle = load(open('logclassifier_mb.plktrain', 'rb'))

# %%
Pickle_pred = classifier_mb_pickle.predict(X_Test)
